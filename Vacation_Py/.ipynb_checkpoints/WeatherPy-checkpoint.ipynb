# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Import dependencies
# %matplotlib notebook

import requests
import pandas as pd
import json
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from citipy import citipy
from random import uniform
from api_keys import weather_api_key
from api_keys import gkey
from pprint import pprint
from urllib.parse import quote

# %% [markdown]
# ## Generate Cities List

# %%
# Creates an empty list for cities, then fills the list based on random latitudes and longitudes

cities = []

for i in range(0,1500):
    city = citipy.nearest_city((uniform(-90,90)), (uniform(-180,180)))
    city = city.city_name
    cities.append(city)

print(len(cities))

# Removes duplicates from cities list
    
cities = list(dict.fromkeys(cities))

print(len(cities))
# Out:
# 1500
# 639

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Builds url to grab weather data for cities

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Builds partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Creates lists for storing weather data for cities

city_name = []
country = []
latitude = []
longitude = []
max_temp = []
humidity = []
wind_speed = []
cloudiness = []

# Sets variable for printing log of each city as it's processed

city_count = 1

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        country.append(response['sys']['country'])
        latitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        cloudiness.append(response['clouds']['all'])
        print(f"City number {city_count} - {response['name']}")
        city_count += 1
    except KeyError:
        continue
# Out:
# City number 1 - Port Alfred
# City number 2 - Vaini
# City number 3 - New Norfolk
# City number 4 - Nikolskoye
# City number 5 - Rikitea
# City number 6 - Kahului
# City number 7 - Arraial do Cabo
# City number 8 - Tuktoyaktuk
# City number 9 - Busselton
# City number 10 - Sokoto
# City number 11 - Havøysund
# City number 12 - Ushuaia
# City number 13 - Bilibino
# City number 14 - Lebu
# City number 15 - Ponta do Sol
# City number 16 - Nishihara
# City number 17 - Wau
# City number 18 - Albany
# City number 19 - Mar del Plata
# City number 20 - Khatanga
# City number 21 - Atuona
# City number 22 - Huaibei
# City number 23 - Ribeira Grande
# City number 24 - Beyneu
# City number 25 - Kapaa
# City number 26 - Bengkulu
# City number 27 - Esim
# City number 28 - Lakselv
# City number 29 - Punta Arenas
# City number 30 - Brae
# City number 31 - Talaya
# City number 32 - Magadan
# City number 33 - Zelenets
# City number 34 - Port Moresby
# City number 35 - Bredasdorp
# City number 36 - Wagga Wagga
# City number 37 - Mataura
# City number 38 - Hilo
# City number 39 - Butaritari
# City number 40 - Bluff
# City number 41 - Esik
# City number 42 - Castro
# City number 43 - La Ronge
# City number 44 - Barrow
# City number 45 - Berlevåg
# City number 46 - Labuhan
# City number 47 - Pevek
# City number 48 - Avarua
# City number 49 - Bolivar
# City number 50 - Hobart
# City number 51 - Bathsheba
# City number 52 - Rio Grande
# City number 53 - Mandera
# City number 54 - Mhlambanyatsi
# City number 55 - Sisimiut
# City number 56 - Kavieng
# City number 57 - Kutum
# City number 58 - Baikunthpur
# City number 59 - Praia da Vitória
# City number 60 - Mehamn
# City number 61 - Nizwá
# City number 62 - College
# City number 63 - Diffa
# City number 64 - Tuatapere
# City number 65 - Port Lincoln
# City number 66 - Hamilton
# City number 67 - Upernavik
# City number 68 - Quatre Cocos
# City number 69 - Puerto Ayora
# City number 70 - Esperance
# City number 71 - Hinton
# City number 72 - Salalah
# City number 73 - Hermanus
# City number 74 - Yellowknife
# City number 75 - San-Pédro
# City number 76 - Vuktyl
# City number 77 - San Patricio
# City number 78 - Baruun-Urt
# City number 79 - Dikson
# City number 80 - Inta
# City number 81 - Jamestown
# City number 82 - Fortuna
# City number 83 - Saint Paul Harbor
# City number 84 - Cockburn Town
# City number 85 - Noumea
# City number 86 - Waingapu
# City number 87 - Douglas
# City number 88 - Kaitangata
# City number 89 - Leningradskiy
# City number 90 - Imbituba
# City number 91 - Uauá
# City number 92 - Hithadhoo
# City number 93 - Itoman
# City number 94 - Saldanha
# City number 95 - Qaanaaq
# City number 96 - Līsakovsk
# City number 97 - Bud
# City number 98 - Caravelas
# City number 99 - Hofn
# City number 100 - Cheb
# City number 101 - Norman Wells
# City number 102 - Bauchi
# City number 103 - Nuuk
# City number 104 - Bonavista
# City number 105 - Chokurdakh
# City number 106 - Lorengau
# City number 107 - Boende
# City number 108 - Acopiara
# City number 109 - İslahiye
# City number 110 - Shelburne
# City number 111 - Rocha
# City number 112 - Linhares
# City number 113 - Galle
# City number 114 - Zeya
# City number 115 - Tasiilaq
# City number 116 - Lompoc
# City number 117 - Souillac
# City number 118 - Provideniya
# City number 119 - Dubbo
# City number 120 - Bairiki Village
# City number 121 - Bandarbeyla
# City number 122 - Almaznyy
# City number 123 - Portland
# City number 124 - Saint-Augustin
# City number 125 - Svetlaya
# City number 126 - Mount Gambier
# City number 127 - Riyadh
# City number 128 - Ruteng
# City number 129 - Willowmore
# City number 130 - Taoudenni
# City number 131 - Lüderitz
# City number 132 - La Reforma
# City number 133 - Kruisfontein
# City number 134 - Aykhal
# City number 135 - Kieta
# City number 136 - Kolda
# City number 137 - Iquitos
# City number 138 - Lavrentiya
# City number 139 - Pozo Colorado
# City number 140 - Dingle
# City number 141 - Yatou
# City number 142 - Touros
# City number 143 - Wanning
# City number 144 - Belaya Gora
# City number 145 - George Town
# City number 146 - Takoradze
# City number 147 - Kafue
# City number 148 - Petropavlovsk-Kamchatskiy
# City number 149 - Pochutla
# City number 150 - Constitución
# City number 151 - Punta de Piedra
# City number 152 - Diu
# City number 153 - Olafsvik
# City number 154 - Airai
# City number 155 - Bethel
# City number 156 - Cape Town
# City number 157 - Birjand
# City number 158 - Praia
# City number 159 - Agadez
# City number 160 - Paamiut
# City number 161 - Harper
# City number 162 - Mont-Dore
# City number 163 - São João da Barra
# City number 164 - Saint Anthony
# City number 165 - Tālbahat
# City number 166 - Nome
# City number 167 - Antalaha
# City number 168 - East London
# City number 169 - Sioux Lookout
# City number 170 - Chui
# City number 171 - Atambua
# City number 172 - Longyearbyen
# City number 173 - Yazman
# City number 174 - Saskylakh
# City number 175 - Khani
# City number 176 - Nouadhibou
# City number 177 - Loukhi
# City number 178 - Pangnirtung
# City number 179 - Alice Springs
# City number 180 - Guerrero Negro
# City number 181 - Abu Kamal
# City number 182 - Dunedin
# City number 183 - Iaciara
# City number 184 - Geraldton
# City number 185 - Djibouti
# City number 186 - Nioro
# City number 187 - Bambous Virieux
# City number 188 - Sibiti
# City number 189 - São Filipe
# City number 190 - Najrān
# City number 191 - Lakes Entrance
# City number 192 - Port Elizabeth
# City number 193 - Camacha
# City number 194 - Norsup
# City number 195 - Puerto del Rosario
# City number 196 - Rigaud
# City number 197 - Katsuura
# City number 198 - Acaraú
# City number 199 - Turbat
# City number 200 - Fairbanks
# City number 201 - San Luis de Gaceno
# City number 202 - Revadanda
# City number 203 - Bismarck
# City number 204 - Yulara
# City number 205 - Zhicheng
# City number 206 - Thompson
# City number 207 - Saint-Philippe
# City number 208 - Codrington
# City number 209 - Walvis Bay
# City number 210 - Ugoofaaru
# City number 211 - Barbacena
# City number 212 - Ubari
# City number 213 - Juneau
# City number 214 - Rassvet
# City number 215 - Röszke
# City number 216 - Kaputa
# City number 217 - Mount Isa
# City number 218 - Hirara
# City number 219 - Nanortalik
# City number 220 - Iralaya
# City number 221 - Fantino
# City number 222 - Valparaíso
# City number 223 - Fenoarivo
# City number 224 - Faanui
# City number 225 - Sangmélima
# City number 226 - Nuquí
# City number 227 - Skellefteå
# City number 228 - High Level
# City number 229 - Hobyo
# City number 230 - Cidreira
# City number 231 - Namatanai
# City number 232 - Vokhma
# City number 233 - Aswān
# City number 234 - Imeni Poliny Osipenko
# City number 235 - Jadu
# City number 236 - Lokosovo
# City number 237 - Totness
# City number 238 - Taft
# City number 239 - Rūdbār
# City number 240 - Zarya
# City number 241 - Aleksandrov Gay
# City number 242 - Bontang
# City number 243 - Tuxtla Gutiérrez
# City number 244 - San Miguel de Cozumel
# City number 245 - La Asuncion
# City number 246 - Clyde River
# City number 247 - Biak
# City number 248 - Richards Bay
# City number 249 - Talnakh
# City number 250 - Mahébourg
# City number 251 - Knysna
# City number 252 - Bilma
# City number 253 - Khovd
# City number 254 - Dongsheng
# City number 255 - Saint George
# City number 256 - Acapulco de Juárez
# City number 257 - Vardø
# City number 258 - Ulaanbaatar
# City number 259 - Karaton
# City number 260 - Warrington
# City number 261 - Lancaster
# City number 262 - Beloha
# City number 263 - Balkhash
# City number 264 - Matagami
# City number 265 - Cumpas
# City number 266 - Sivas Province
# City number 267 - Karratha
# City number 268 - Seoul
# City number 269 - Flinders
# City number 270 - Port Keats
# City number 271 - Port Hedland
# City number 272 - Sinjār
# City number 273 - Peniche
# City number 274 - Russell
# City number 275 - Daru
# City number 276 - Sos'va
# City number 277 - Yairipok
# City number 278 - Concordia
# City number 279 - Hong Kong
# City number 280 - Koshurnikovo
# City number 281 - Nador
# City number 282 - Cherskiy
# City number 283 - Marsaxlokk
# City number 284 - Iqaluit
# City number 285 - Lagoa
# City number 286 - Vao
# City number 287 - Kuminskiy
# City number 288 - Coahuayana Viejo
# City number 289 - Iranshahr
# City number 290 - Conde
# City number 291 - Baghdad
# City number 292 - Christchurch
# City number 293 - Egvekinot
# City number 294 - Abalak
# City number 295 - Manokwari
# City number 296 - Necochea
# City number 297 - Sinnamary
# City number 298 - Port Blair
# City number 299 - Roebourne
# City number 300 - Ahipara
# City number 301 - Ilulissat
# City number 302 - Prince Rupert
# City number 303 - Dukat
# City number 304 - Bend
# City number 305 - Zambezi
# City number 306 - Anuradhapura
# City number 307 - Bhag
# City number 308 - Rome
# City number 309 - Monticello
# City number 310 - Los Llanos de Aridane
# City number 311 - Saint-Pierre
# City number 312 - Bandundu Province
# City number 313 - Meulaboh
# City number 314 - Shimanovsk
# City number 315 - Monrovia
# City number 316 - Carnarvon
# City number 317 - Bacsay
# City number 318 - Saint-Joseph
# City number 319 - Caher
# City number 320 - Tomigusuku
# City number 321 - Goderich
# City number 322 - Norwich
# City number 323 - Methóni
# City number 324 - Novhorodka
# City number 325 - Samarai
# City number 326 - Hasaki
# City number 327 - Vysokogornyy
# City number 328 - Puerto Escondido
# City number 329 - Pisco
# City number 330 - Popondetta
# City number 331 - Waiouru
# City number 332 - Balasheyka
# City number 333 - Bubaque
# City number 334 - Shirokiy
# City number 335 - Sobolevo
# City number 336 - San Jose
# City number 337 - Azul
# City number 338 - Bendigo
# City number 339 - Nicoya
# City number 340 - Koksijde
# City number 341 - Bam
# City number 342 - Gizo Government Station
# City number 343 - Batagay
# City number 344 - Ambon City
# City number 345 - Tokur
# City number 346 - Broome
# City number 347 - Lázaro Cárdenas
# City number 348 - Tautira
# City number 349 - Mandalī
# City number 350 - Erzin
# City number 351 - Havre-St-Pierre
# City number 352 - Kortkeros
# City number 353 - Helena
# City number 354 - Mago
# City number 355 - Avera
# City number 356 - Porto Velho
# City number 357 - Beaufort
# City number 358 - Emirdağ
# City number 359 - Torbay
# City number 360 - Assiut
# City number 361 - Skibbereen
# City number 362 - Kidal
# City number 363 - San Pedro de Macorís
# City number 364 - Wahpeton
# City number 365 - Eatonton
# City number 366 - Buseresere
# City number 367 - Igrim
# City number 368 - Vila Velha
# City number 369 - Nhulunbuy
# City number 370 - São Félix do Xingu
# City number 371 - Xiongzhou
# City number 372 - Porto Franco
# City number 373 - Guilin
# City number 374 - Vadlapūdi
# City number 375 - Pacific Grove
# City number 376 - Shelomi
# City number 377 - Ucluelet
# City number 378 - Frutigen
# City number 379 - Peace River
# City number 380 - Santiago de Cuba
# City number 381 - Cap Malheureux
# City number 382 - Kurchum
# City number 383 - Severo-Kuril'sk
# City number 384 - Torres
# City number 385 - Lircay
# City number 386 - Halayhay
# City number 387 - Ruidoso
# City number 388 - Nago
# City number 389 - Monkey Hill
# City number 390 - Aklavik
# City number 391 - Khandyga
# City number 392 - Curuguaty
# City number 393 - Kavaratti
# City number 394 - Nantucket
# City number 395 - San Miguel de Tucumán
# City number 396 - Maralal
# City number 397 - Sechura
# City number 398 - Padang
# City number 399 - Moyale
# City number 400 - Port Augusta
# City number 401 - Saint-Ambroise
# City number 402 - Billings Metropolitan Area
# City number 403 - Governador Dix-Sept Rosado
# City number 404 - Rogers
# City number 405 - Black River
# City number 406 - Yamethin
# City number 407 - Hay River
# City number 408 - Chabahar
# City number 409 - Adré
# City number 410 - Poum
# City number 411 - Port-Gentil
# City number 412 - Burnie
# City number 413 - Nelson Bay
# City number 414 - Mosetse
# City number 415 - Porto Santo
# City number 416 - Noyabrsk
# City number 417 - Ulladulla
# City number 418 - Porto-Novo
# City number 419 - Kholuy
# City number 420 - Chulym
# City number 421 - Plettenberg Bay
# City number 422 - Ust-Tsilma
# City number 423 - Saint-François
# City number 424 - Casablanca
# City number 425 - Boulsa
# City number 426 - Nurota
# City number 427 - Arāria
# City number 428 - San Borja
# City number 429 - Yangi Marg`ilon
# City number 430 - Mapiri
# City number 431 - Melur
# City number 432 - Jerantut
# City number 433 - Te Anau
# City number 434 - Bystryy Istok
# City number 435 - Newport
# City number 436 - Uva
# City number 437 - Mackay
# City number 438 - Kiryat Gat
# City number 439 - Gaoua
# City number 440 - Manado
# City number 441 - Dunkirk
# City number 442 - Shushenskoye
# City number 443 - Natchitoches
# City number 444 - Oyama
# City number 445 - Bodden Town
# City number 446 - Narón
# City number 447 - Yuli
# City number 448 - Verkh-Usugli
# City number 449 - Ambulu
# City number 450 - Mahabalipuram
# City number 451 - Zhigansk
# City number 452 - Mendi
# City number 453 - Sur
# City number 454 - Kozhva
# City number 455 - Aberdeen
# City number 456 - Laguna
# City number 457 - Maniitsoq
# City number 458 - Madison Heights
# City number 459 - Pulandian
# City number 460 - Mossamedes
# City number 461 - Albury
# City number 462 - Kailua
# City number 463 - Narsaq
# City number 464 - Cabedelo
# City number 465 - Viedma
# City number 466 - Tutayev
# City number 467 - Kismayo
# City number 468 - Moose Factory
# City number 469 - Asău
# City number 470 - Gusau
# City number 471 - Turukhansk
# City number 472 - ‘Āhuimanu
# City number 473 - Maraã
# City number 474 - Tiksi
# City number 475 - Ilo
# City number 476 - Sotnikovo
# City number 477 - Grand Gaube
# City number 478 - Castro Alves
# City number 479 - Minot
# City number 480 - Lake Shasta
# City number 481 - Jiaojiang
# City number 482 - Brewster
# City number 483 - Penzance
# City number 484 - Moranbah
# City number 485 - Tabou
# City number 486 - Key West
# City number 487 - Mga
# City number 488 - Tessalit
# City number 489 - Udachny
# City number 490 - Oneonta
# City number 491 - Cayenne
# City number 492 - Karasjok
# City number 493 - Kirensk
# City number 494 - Saint-Paul
# City number 495 - Fukuechō
# City number 496 - Chernushka
# City number 497 - Xingcheng
# City number 498 - Kupang
# City number 499 - Urengoy
# City number 500 - Saint Paul
# City number 501 - Vila Franca do Campo
# City number 502 - Florianópolis
# City number 503 - Grindavik
# City number 504 - Honolulu
# City number 505 - Ancud
# City number 506 - Tete
# City number 507 - Puerto Baquerizo Moreno
# City number 508 - Puerto Madryn
# City number 509 - Gravdal
# City number 510 - Dwārka
# City number 511 - Putina
# City number 512 - Salinópolis
# City number 513 - Mandalgovi
# City number 514 - Verkhoyansk
# City number 515 - Whitecourt
# City number 516 - Dabola
# City number 517 - Denpasar
# City number 518 - Binga
# City number 519 - Muravlenko
# City number 520 - Kysyl-Syr
# City number 521 - Whitehorse
# City number 522 - Ponta Delgada
# City number 523 - Kushima
# City number 524 - Chicama
# City number 525 - Kerema
# City number 526 - Bousso
# City number 527 - Cabo San Lucas
# City number 528 - Pemangkat
# City number 529 - Victoria Point
# City number 530 - Okakarara
# City number 531 - Āreka
# City number 532 - Pitimbu
# City number 533 - La Rioja
# City number 534 - Kununurra
# City number 535 - Haines Junction
# City number 536 - Jaciara
# City number 537 - Liwale
# City number 538 - Inuvik
# City number 539 - Hope
# City number 540 - Quryq
# City number 541 - Shimoda
# City number 542 - Palu
# City number 543 - Carutapera
# City number 544 - Kuloy
# City number 545 - Lethem
# City number 546 - Anadyr
# City number 547 - Mareeba
# City number 548 - San Ignacio
# City number 549 - Puerto Suárez
# City number 550 - Sabzawār
# City number 551 - Kargat
# City number 552 - Usinsk
# City number 553 - Gorontalo
# City number 554 - Laas
# City number 555 - Māgadi
# City number 556 - The Valley
# City number 557 - Kloulklubed
# City number 558 - Naze
# City number 559 - Murgab
# City number 560 - Sembakung
# City number 561 - Baffa
# City number 562 - Kalmunai
# City number 563 - Raudeberg
# City number 564 - Bumba
# City number 565 - Yerbogachën
# City number 566 - Beringovskiy
# City number 567 - Abu Dhabi
# City number 568 - Boa Vista
# City number 569 - Belomorsk
# City number 570 - Yumen
# City number 571 - Faya
# City number 572 - Invermere
# City number 573 - Alofi
# City number 574 - Sibut
# City number 575 - Ostrovnoy
# City number 576 - Shache
# City number 577 - Isangel
# City number 578 - Vestmannaeyjar
# City number 579 - Kinablangan
# City number 580 - Haldībāri
# City number 581 - Arlit
# City number 582 - Okhotsk
# City number 583 - Bāfq
# City number 584 - Araouane
# City number 585 - Saquarema
# City number 586 - Dubrovytsya
# City number 587 - Umluj
# City number 588 - Krasnosel'kup

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Creates DataFrame from weather variable lists and exports to csv

df_cities_weather = pd.DataFrame({"City": city_name,
                                  "Country": country,
                                  "Latitude": latitude,
                                  "Longitude": longitude,
                                  "Max Temp (F)": max_temp,
                                  "Humidity (%)": humidity,
                                  "Wind Speed (mph)": wind_speed,
                                  "Cloudiness": cloudiness})
                                 

df_cities_weather.head()
df_cities_weather.to_csv("cities_weather.csv", index=False)

# %%
df_cities_weather.describe()
# Out:
#          Latitude   Longitude  Max Temp (F)  Humidity (%)  Wind Speed (mph)  \
# count  588.000000  588.000000    588.000000    588.000000        588.000000
# mean    20.054660   20.791616     60.421531     71.267007          8.193401
# std     33.296884   90.709132     20.427570     21.139316          5.446594
# min    -54.800000 -179.170000      8.220000     10.000000          0.110000
# 25%     -7.562500  -57.855000     44.010000     60.000000          4.192500
# 50%     22.625000   26.770000     64.990000     76.000000          6.930000
# 75%     48.555000  102.395000     78.010000     88.000000         11.410000
# max     78.220000  179.320000     96.800000    100.000000         29.950000
#
#        Cloudiness
# count  588.000000
# mean    49.670068
# std     38.784777
# min      0.000000
# 25%      5.750000
# 50%     49.000000
# 75%     90.000000
# max    100.000000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Creates figure for comparing latitude and temperature
fig1, ax1 = plt.subplots(figsize=(5,5))
ax1.scatter(df_cities_weather["Latitude"], df_cities_weather["Max Temp (F)"])
ax1.set(xlabel="Latitude", ylabel="Max Temperature (F)")
plt.title("Latitude vs. Max Temperature (F)")

plt.tight_layout()

fig1.savefig("TemperatureVsLatitude.png")

print("As depicted in the graph above, the highest temperature cities are concentrated within roughly 20 degrees of latitude above or below the equator, and drop off sharply as latitude extends above 40 degrees north. This can be explained by the relative distance of the sun over these latitudes.")
# Out:
# <img src="data:image/png;base64,..." width="500">
# As depicted in the graph above, the highest temperature cities are concentrated within roughly 20 degrees of latitude above or below the equator, and drop off sharply as latitude extends above 40 degrees north. This can be explained by the relative distance of the sun over these latitudes.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Creates figure for comparing latitude and humidity
fig2, ax2 = plt.subplots(figsize=(5,5))
ax2.scatter(df_cities_weather["Latitude"], df_cities_weather["Humidity (%)"])
ax2.set(xlabel="Latitude", ylabel="Humidity (%)")
plt.title("Latitude vs. Humidity (%)")

plt.tight_layout()

fig2.savefig("HumidityVsLatitude.png")

print("As depicted in the graph above, humidity does not appear to have a direct relationship with latitude, as there is a wide degree of variation in humidity among cities located along the same latitudes.")
# Out:
# <img src="data:image/png;base64,..." width="500">
# As depicted in the graph above, humidity does not appear to have a direct relationship with latitude, as there is a wide degree of variation in humidity among cities located along the same latitudes.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Creates figure for comparing latitude and cloudiness
fig3, ax3 = plt.subplots(figsize=(5,5))
ax3.scatter(df_cities_weather["Latitude"], df_cities_weather["Cloudiness"])
ax3.set(xlabel="Latitude", ylabel="Cloudiness")
plt.title("Latitude vs. Cloudiness")

plt.tight_layout()

fig3.savefig("CLoudinessVsLatitude.png")

print("As depicted in the graph above, cloudiness does not appear to have a direct relationship with latitude, as there is a wide degree of variation in cloudiness among cities located along the same latitudes.")
# Out:
# <img src="data:image/png;base64,..." width="500">
# As depicted in the graph above, cloudiness does not appear to have a direct relationship with latitude, as there is a wide degree of variation in cloudiness among cities located along the same latitudes.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Creates figure for comparing latitude and cloudiness
fig4, ax4 = plt.subplots(figsize=(5,5))
ax4.scatter(df_cities_weather["Latitude"], df_cities_weather["Wind Speed (mph)"])
ax4.set(xlabel="Latitude", ylabel="Wind Speed (mph)")
plt.title("Latitude vs. Wind Speed (mph)")

plt.tight_layout()

fig4.savefig("WindSpeedVsLatitude.png")

print("As depicted in the graph above, wind speed does not appear to have a direct relationship with latitude, as there is a wide degree of variation in wind speed among cities located along the same latitudes, although the highest wind speeds are often at the extreme south or north of the globe, which could be representative of the relative flatness of these regions.")
# Out:
# <img src="data:image/png;base64,..." width="500">
# As depicted in the graph above, wind speed does not appear to have a direct relationship with latitude, as there is a wide degree of variation in wind speed among cities located along the same latitudes, although the highest wind speeds are often at the extreme south or north of the globe, which could be representative of the relative flatness of these regions.

# %% [markdown]
# ## Linear Regression

# %%
df_northern_cities = df_cities_weather.loc[df_cities_weather["Latitude"] > 0]

df_southern_cities = df_cities_weather.loc[df_cities_weather["Latitude"] < 0]

df_northern_cities.describe()
# Out:
#          Latitude   Longitude  Max Temp (F)  Humidity (%)  Wind Speed (mph)  \
# count  405.000000  405.000000    405.000000    405.000000        405.000000
# mean    38.565012   11.821333     55.615333     71.716049          8.303136
# std     20.703590   87.635916     21.789299     22.353170          5.592126
# min      0.130000 -179.170000      8.220000     10.000000          0.110000
# 25%     20.890000  -69.360000     36.770000     61.000000          4.380000
# 50%     39.400000   22.470000     57.200000     77.000000          6.930000
# 75%     56.250000   79.800000     77.000000     89.000000         11.210000
# max     78.220000  179.320000     92.280000    100.000000         29.950000
#
#        Cloudiness
# count  405.000000
# mean    49.313580
# std     40.095405
# min      0.000000
# 25%      2.000000
# 50%     47.000000
# 75%     90.000000
# max    100.000000

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Creates figure for comparing latitude and temperature in the northern hemisphere
fig5, ax5 = plt.subplots(figsize=(5,5))
ax5.scatter(df_northern_cities["Latitude"], df_northern_cities["Max Temp (F)"])
ax5.set(xlabel="Latitude", ylabel="Max Temperature (F)")
plt.title("Latitude vs. Max Temperature (F) in the Northern Hemisphere")

plt.tight_layout()

# Performs linear regression on latitude vs. temperature
(slope1, intercept1, rvalue1, pvalue1, stderr1) = stats.linregress(df_northern_cities["Latitude"], df_northern_cities["Max Temp (F)"])

# Gets regression values and plots regression line with line equation
regress_values1 = df_northern_cities["Latitude"] * slope1 + intercept1

line_eq1 = "y = " + str(round(slope1,2)) + "x +" + str(round(intercept1,2))

plt.plot(df_northern_cities["Latitude"], regress_values1, "r-")
plt.annotate(line_eq1, (5,5), fontsize=15, color="red")

fig5.savefig("NorthernHemishphere-TemperatureVsLatitude.png")

print(f"As depicted in the graph above, the highest temperature cities are concentrated within roughly 20 degrees of latitude above the equator, and drop off sharply as latitude extends above 40 degrees north. The r-value is {str(round(rvalue1,2))}.")
# Out:
# <img src="data:image/png;base64,..." width="500">
# As depicted in the graph above, the highest temperature cities are concentrated within roughly 20 degrees of latitude above the equator, and drop off sharply as latitude extends above 40 degrees north. The r-value is -0.89.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Creates figure for comparing latitude and temperature in the southern hemisphere
fig6, ax6 = plt.subplots(figsize=(5,5))
ax6.scatter(df_southern_cities["Latitude"], df_southern_cities["Max Temp (F)"])
ax6.set(xlabel="Latitude", ylabel="Max Temperature (F)")
plt.title("Latitude vs. Max Temperature (F) in the Southern Hemisphere")

plt.tight_layout()

# Performs linear regression on latitude vs. temperature
(slope2, intercept2, rvalue2, pvalue2, stderr2) = stats.linregress(df_southern_cities["Latitude"], df_southern_cities["Max Temp (F)"])

# Gets regression values and plots regression line with line equation
regress_values2 = df_southern_cities["Latitude"] * slope2 + intercept2

line_eq2 = "y = " + str(round(slope2,2)) + "x +" + str(round(intercept2,2))

plt.plot(df_southern_cities["Latitude"], regress_values2, "r-")
plt.annotate(line_eq2, (-45,45), fontsize=15, color="red")

fig6.savefig("SouthernHemishphere-TemperatureVsLatitude.png")

print(f"As depicted in the graph above, the highest temperature cities are concentrated within roughly 20 degrees of latitude below the equator, and drop off sharply as latitude extends below 40 degrees south. The r-value is {str(round(rvalue2,2))}.")
# Out:
# <img src="data:image/png;base64,..." width="500">
# As depicted in the graph above, the highest temperature cities are concentrated within roughly 20 degrees of latitude below the equator, and drop off sharply as latitude extends below 40 degrees south. The r-value is 0.63.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Creates figure for comparing humidity and latitude in the northern hemisphere
fig7, ax7 = plt.subplots(figsize=(5,5))
ax7.scatter(df_northern_cities["Latitude"], df_northern_cities["Humidity (%)"])
ax7.set(xlabel="Latitude", ylabel="Humidity (%)")
plt.title("Latitude vs. Humidity (%) in the Northern Hemisphere")

plt.tight_layout()

# Performs linear regression on latitude vs. humidity
(slope3, intercept3, rvalue3, pvalue3, stderr3) = stats.linregress(df_northern_cities["Latitude"], df_northern_cities["Humidity (%)"])

# Gets regression values and plots regression line with line equation
regress_values3 = df_northern_cities["Latitude"] * slope3 + intercept3

line_eq3 = "y = " + str(round(slope3,2)) + "x +" + str(round(intercept3,2))

plt.plot(df_northern_cities["Latitude"], regress_values3, "r-")
plt.annotate(line_eq3, (10,10), fontsize=15, color="red")

fig7.savefig("NorthernHemishphere-HumidityVsLatitude.png")

print(f"As depicted in the graph above, humidity does not appear to have a strong relationship with latitude, as there is a wide degree of variation in humidity among cities located along the same latitudes. The r-value is {str(round(rvalue3,2))}.")
# Out:
# <img src="data:image/png;base64,..." width="500">
# As depicted in the graph above, humidity does not appear to have a strong relationship with latitude, as there is a wide degree of variation in humidity among cities located along the same latitudes. The r-value is 0.24.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Creates figure for comparing humidity and latitude in the northern hemisphere
fig8, ax8 = plt.subplots(figsize=(5,5))
ax8.scatter(df_southern_cities["Latitude"], df_southern_cities["Humidity (%)"])
ax8.set(xlabel="Latitude", ylabel="Humidity (%)")
plt.title("Latitude vs. Humidity (%) in the Southern Hemisphere")

plt.tight_layout()

# Performs linear regression on latitude vs. humidity
(slope4, intercept4, rvalue4, pvalue4, stderr4) = stats.linregress(df_southern_cities["Latitude"], df_southern_cities["Humidity (%)"])

# Gets regression values and plots regression line with line equation
regress_values4 = df_southern_cities["Latitude"] * slope4 + intercept4

line_eq4 = "y = " + str(round(slope4,2)) + "x +" + str(round(intercept4,2))

plt.plot(df_southern_cities["Latitude"], regress_values4, "r-")
plt.annotate(line_eq4, (-40,20), fontsize=15, color="red")

fig8.savefig("SouthernHemishphere-HumidityVsLatitude.png")

print(f"As depicted in the graph above, humidity does not appear to have a strong relationship with latitude, as there is a wide degree of variation in humidity among cities located along the same latitudes. The r-value is {str(round(rvalue4,2))}.")
# Out:
# <img src="data:image/png;base64,..." width="500">
# As depicted in the graph above, humidity does not appear to have a strong relationship with latitude, as there is a wide degree of variation in humidity among cities located along the same latitudes. The r-value is 0.1.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Creates figure for comparing cloudiness and latitude in the northern hemisphere
fig9, ax9 = plt.subplots(figsize=(5,5))
ax9.scatter(df_northern_cities["Latitude"], df_northern_cities["Cloudiness"])
ax9.set(xlabel="Latitude", ylabel="Cloudiness")
plt.title("Latitude vs. Cloudiness in the Northern Hemisphere")

plt.tight_layout()

# Performs linear regression on latitude vs. cloudiness
(slope5, intercept5, rvalue5, pvalue5, stderr5) = stats.linregress(df_northern_cities["Latitude"], df_northern_cities["Cloudiness"])

# Gets regression values and plots regression line with line equation
regress_values5 = df_northern_cities["Latitude"] * slope5 + intercept5

line_eq5 = "y = " + str(round(slope5,2)) + "x +" + str(round(intercept5,2))

plt.plot(df_northern_cities["Latitude"], regress_values5, "r-")
plt.annotate(line_eq5, (5,5), fontsize=15, color="red")

fig9.savefig("NorthernHemishphere-CloudinessVsLatitude.png")

print(f"As depicted in the graph above, cloudiness does not appear to have a strong relationship with latitude, as there is a wide degree of variation in cloudiness among cities located along the same latitudes. The r-value is {str(round(rvalue5,2))}.")
# Out:
# <img src="data:image/png;base64,..." width="500">
# As depicted in the graph above, cloudiness does not appear to have a strong relationship with latitude, as there is a wide degree of variation in cloudiness among cities located along the same latitudes. The r-value is 0.15.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Creates figure for comparing cloudiness and latitude in the southern hemisphere
fig10, ax10 = plt.subplots(figsize=(5,5))
ax10.scatter(df_southern_cities["Latitude"], df_southern_cities["Cloudiness"])
ax10.set(xlabel="Latitude", ylabel="Cloudiness")
plt.title("Latitude vs. Cloudiness in the Southern Hemisphere")

plt.tight_layout()

# Performs linear regression on latitude vs. cloudiness
(slope6, intercept6, rvalue6, pvalue6, stderr6) = stats.linregress(df_southern_cities["Latitude"], df_southern_cities["Cloudiness"])

# Gets regression values and plots regression line with line equation
regress_values6 = df_southern_cities["Latitude"] * slope6 + intercept6

line_eq6 = "y = " + str(round(slope6,2)) + "x +" + str(round(intercept6,2))

plt.plot(df_southern_cities["Latitude"], regress_values6, "r-")
plt.annotate(line_eq6, (-55,10), fontsize=15, color="red")

fig10.savefig("SouthernHemishphere-CloudinessVsLatitude.png")

print(f"As depicted in the graph above, cloudiness does not appear to have a strong relationship with latitude, as there is a wide degree of variation in cloudiness among cities located along the same latitudes. The r-value is {str(round(rvalue6,2))}.")
# Out:
# <img src="data:image/png;base64,..." width="500">
# As depicted in the graph above, cloudiness does not appear to have a strong relationship with latitude, as there is a wide degree of variation in cloudiness among cities located along the same latitudes. The r-value is 0.02.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Creates figure for comparing windspeed and latitude in the northern hemisphere
fig11, ax11 = plt.subplots(figsize=(5,5))
ax11.scatter(df_northern_cities["Latitude"], df_northern_cities["Wind Speed (mph)"])
ax11.set(xlabel="Latitude", ylabel="Wind Speed (mph)")
plt.title("Latitude vs. Wind Speed in the Northern Hemisphere")

plt.tight_layout()

# Performs linear regression on latitude vs. wind speed
(slope7, intercept7, rvalue7, pvalue7, stderr7) = stats.linregress(df_northern_cities["Latitude"], df_northern_cities["Wind Speed (mph)"])

# Gets regression values and plots regression line with line equation
regress_values7 = df_northern_cities["Latitude"] * slope7 + intercept7

line_eq7 = "y = " + str(round(slope7,2)) + "x +" + str(round(intercept7,2))

plt.plot(df_northern_cities["Latitude"], regress_values7, "r-")
plt.annotate(line_eq7, (5,22), fontsize=15, color="red")

fig11.savefig("NorthernHemishphere-WindSpeedVsLatitude.png")

print(f"As depicted in the graph above, wind speed does not appear to have a strong relationship with latitude, as there is a wide degree of variation in wind speed among cities located along the same latitudes, although the highest wind speeds are often at the extreme north of the globe. The r-value is {str(round(rvalue7,2))}.")
# Out:
# <img src="data:image/png;base64,..." width="500">
# As depicted in the graph above, wind speed does not appear to have a strong relationship with latitude, as there is a wide degree of variation in wind speed among cities located along the same latitudes, although the highest wind speeds are often at the extreme north of the globe. The r-value is 0.2.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Creates figure for comparing wind speed and latitude in the southern hemisphere
fig12, ax12 = plt.subplots(figsize=(5,5))
ax12.scatter(df_southern_cities["Latitude"], df_southern_cities["Wind Speed (mph)"])
ax12.set(xlabel="Latitude", ylabel="Wind Speed (mph)")
plt.title("Latitude vs. Wind Speed in the Southern Hemisphere")

plt.tight_layout()

# Performs linear regression on latitude vs. wind speed
(slope8, intercept8, rvalue8, pvalue8, stderr8) = stats.linregress(df_southern_cities["Latitude"], df_southern_cities["Wind Speed (mph)"])

# Gets regression values and plots regression line with line equation
regress_values8 = df_southern_cities["Latitude"] * slope8 + intercept8

line_eq8 = "y = " + str(round(slope8,2)) + "x +" + str(round(intercept8,2))

plt.plot(df_southern_cities["Latitude"], regress_values8, "r-")
plt.annotate(line_eq8, (-50,20), fontsize=15, color="red")

fig12.savefig("SouthernHemishphere-WindSpeedVsLatitude.png")

print(f"As depicted in the graph above, wind speed does not appear to have a strong relationship with latitude, as there is a wide degree of variation in wind speed among cities located along the same latitudes. The r-value is {str(round(rvalue8,2))}.")
# Out:
# <img src="data:image/png;base64,..." width="500">
# As depicted in the graph above, wind speed does not appear to have a strong relationship with latitude, as there is a wide degree of variation in wind speed among cities located along the same latitudes. The r-value is -0.21.
